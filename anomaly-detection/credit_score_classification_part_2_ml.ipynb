# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re
import scipy.stats as stats
from tqdm import tqdm
import math
from termcolor import cprint
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, cross_val_score
from sklearn.metrics import f1_score, classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb

import missingno as msno
import warnings
warnings.filterwarnings('ignore')

SEED = 42

# %%
df = pd.read_csv('credit_score_clean_data.csv')

# %% [markdown]
# ## Handel Categorical Data

# %%
df.drop(columns=['ID', 'Customer_ID', 'Name', 'SSN', 'Credit_Mix'], inplace=True)

# %%
df.describe(include='object').T
# Out:
#                         count unique                             top   freq
# Occupation             150000     15                          Lawyer  10644
# Type_of_Loan           150000   6261                         No Data  17112
# Credit_History_Age     150000    408          17 Years and 10 Months   1100
# Payment_of_Min_Amount  150000      3                             Yes  78484
# Payment_Behaviour      150000      6  Low_spent_Small_value_payments  42046
# Credit_Score           100000      3                        Standard  53174

# %% [markdown]
# ## Handel Numerical Data

# %%
df.describe(exclude='object').T
# Out:
#                              count          mean           std          min  \
# Month                     150000.0      6.500000      3.452064     1.000000
# Age                       150000.0     33.479060     10.767158    14.000000
# Annual_Income             150000.0  50505.123449  38299.358260  7005.930000
# Monthly_Inhand_Salary     150000.0   4192.525296   3182.728812   303.645417
# Num_Bank_Accounts         150000.0      5.368707      2.594388    -1.000000
# Num_Credit_Card           150000.0      5.533660      2.068672     0.000000
# Interest_Rate             150000.0     14.532080      8.741316     1.000000
# Num_of_Loan               150000.0      3.532880      2.446352     0.000000
# Delay_from_due_date       150000.0     21.070393     14.813531    -1.000000
# Num_of_Delayed_Payment    150000.0     13.301967      6.263060    -2.000000
# Changed_Credit_Limit      150000.0     10.468630      6.608250     0.500000
# Num_Credit_Inquiries      150000.0      6.278940      3.957925     0.000000
# Outstanding_Debt          150000.0   1426.220376   1155.127101     0.230000
# Credit_Utilization_Ratio  150000.0     28.350168      3.856992    20.000000
# Total_EMI_per_month       150000.0    113.126372    144.283689     0.000000
# Amount_invested_monthly   150000.0    648.688135   2081.547384     0.000000
# Monthly_Balance           150000.0    392.937052    201.716752     0.007760
#
#                                    25%           50%           75%  \
# Month                         3.750000      6.500000      9.250000
# Age                          25.000000     33.000000     42.000000
# Annual_Income             19342.972500  36999.705000  71683.470000
# Monthly_Inhand_Salary      1625.558333   3091.000000   5951.373333
# Num_Bank_Accounts             3.000000      5.000000      7.000000
# Num_Credit_Card               4.000000      5.000000      7.000000
# Interest_Rate                 7.000000     13.000000     20.000000
# Num_of_Loan                   2.000000      3.000000      5.000000
# Delay_from_due_date          10.000000     18.000000     28.000000
# Num_of_Delayed_Payment        9.000000     14.000000     18.000000
# Changed_Credit_Limit          5.380000      9.400000     14.830000
# Num_Credit_Inquiries          3.000000      6.000000      9.000000
# Outstanding_Debt            566.072500   1166.155000   1945.962500
# Credit_Utilization_Ratio     25.053395     27.781320     31.610789
# Total_EMI_per_month          29.916254     67.946920    152.294478
# Amount_invested_monthly      70.574798    130.548923    258.783441
# Monthly_Balance             267.720142    333.921243    463.423068
#
#                                     max
# Month                         12.000000
# Age                           56.000000
# Annual_Income             179987.280000
# Monthly_Inhand_Salary      15204.633333
# Num_Bank_Accounts             11.000000
# Num_Credit_Card               11.000000
# Interest_Rate                 34.000000
# Num_of_Loan                    9.000000
# Delay_from_due_date           62.000000
# Num_of_Delayed_Payment        25.000000
# Changed_Credit_Limit          29.980000
# Num_Credit_Inquiries          17.000000
# Outstanding_Debt            4998.070000
# Credit_Utilization_Ratio      35.793038
# Total_EMI_per_month         1779.103254
# Amount_invested_monthly    10000.000000
# Monthly_Balance             1183.930696

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### Credit History Age

# %%
df['Credit_History_Age'] = df['Credit_History_Age'].astype('category')

# %%
def split_year_month(date, is_month=None):
    date = date.replace('Years', '').replace('Months', '')
    date_list = date.split('and')
    
    if is_month:
        return int(date_list[1].strip())
    
    return int(date_list[0].strip())

# %%
df['Credit_History_Age_Year'] = df['Credit_History_Age'].apply(lambda x: split_year_month(x, is_month=False))

# %%
df['Credit_History_Age_Month'] = df['Credit_History_Age'].apply(lambda x: split_year_month(x, is_month=True))

# %%
df.drop(columns='Credit_History_Age', inplace=True)

# %% [markdown]
# ## Split df train and test

# %%
df_train = df[df['Credit_Score'].notna() == True]
df_test = df[df['Credit_Score'].isna() == True]

# %%
X = df_train.drop(columns='Credit_Score')
y = df_train[['Credit_Score']]

# %% [markdown]
# ## Encoding

# %%
def multiple_label_encoder(df):
    cat_col_list = df.select_dtypes(exclude=[np.number]).columns
    df[cat_col_list]= df[cat_col_list].apply(LabelEncoder().fit_transform)
    
    return df

# %%
X = multiple_label_encoder(X)
y = multiple_label_encoder(y)

# %% [markdown]
# ## Scaling

# %%
sc = StandardScaler()
X_scaled = sc.fit_transform(X)

# %% [markdown]
# ## Split X train and X test

# %%
X_train, X_val, y_train, y_val = train_test_split(X_scaled, y, random_state=SEED, test_size = 0.2, stratify=y)

# %% [markdown]
# ## Modeling

# %%
### Inbalanced data
np.unique(y, return_counts=True)
# Out:
# (array([0, 1, 2]), array([17828, 28998, 53174]))

# %%
rf = RandomForestClassifier(n_estimators=100, class_weight='balanced', max_depth=22)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_val)

# %%
print(classification_report(y_val, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.82      0.72      3566
#            1       0.79      0.82      0.81      5799
#            2       0.86      0.76      0.81     10635
#
#     accuracy                           0.79     20000
#    macro avg       0.77      0.80      0.78     20000
# weighted avg       0.80      0.79      0.79     20000

# %%
y_train_pred_rf =  rf.predict(X_train)
print(classification_report(y_train, y_train_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.89     14262
#            1       0.93      0.97      0.95     23199
#            2       1.00      0.89      0.94     42539
#
#     accuracy                           0.94     80000
#    macro avg       0.91      0.96      0.93     80000
# weighted avg       0.94      0.94      0.94     80000

# %%
rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': 'balanced',
#  'criterion': 'gini',
#  'max_depth': 22,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# ### Hyperparameter Tuning

# %%
# params = {
#     'n_estimators' : range(50, 200, 50),
#     'max_depth': range(3, 21, 3),
#     'min_samples_leaf': range(1,5),
#     'criterion':['gini', 'entropy'],
#     'oob_score'   : [True]
# }

# %%
# gs_obj = GridSearchCV(rf, param_grid=params, scoring='f1',  cv=5)

# %%
# gs_obj.fit(X_train, y_train)
# y_pred_rf = gs_obj.predict(X_val)

# %% [markdown]
# ## XGBoost

# %%
xgb_obj = xgb.XGBClassifier()
xgb_obj.fit(X_train, y_train)
y_pred_xgb = xgb_obj.predict(X_val)

# %%
print(classification_report(y_val, y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.67      0.69      3566
#            1       0.78      0.73      0.75      5799
#            2       0.77      0.81      0.79     10635
#
#     accuracy                           0.76     20000
#    macro avg       0.75      0.74      0.74     20000
# weighted avg       0.76      0.76      0.76     20000

# %%
y_train_pred_xgb = xgb_obj.predict(X_train)
print(classification_report(y_train, y_train_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.76      0.78     14262
#            1       0.81      0.79      0.80     23199
#            2       0.82      0.85      0.84     42539
#
#     accuracy                           0.82     80000
#    macro avg       0.81      0.80      0.81     80000
# weighted avg       0.82      0.82      0.82     80000

# %% [markdown]
# ## GridSearch

# %%
param_grid = {
    'n_estimators' : [100],
    'learning_rate': np.linspace(0.01, 0.3, 2).round(3),
    'max_depth'    : [5, 6],    
}

# %%
xgb_obj_grs = xgb.XGBClassifier()
grs_obj_xgb = GridSearchCV(xgb_obj_grs, param_grid, scoring='f1', cv=5, n_jobs=-1 )

# %%
grs_obj_xgb.fit(X_train, y_train)
y_pred_grs = grs_obj_xgb.predict(X_val)
# Out:
# /Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 216, in __call__
#     return self._score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1123, in f1_score
#     return fbeta_score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1261, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1544, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1365, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 216, in __call__
#     return self._score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1123, in f1_score
#     return fbeta_score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1261, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1544, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1365, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 216, in __call__
#     return self._score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1123, in f1_score
#     return fbeta_score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1261, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1544, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1365, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 216, in __call__
#     return self._score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1123, in f1_score
#     return fbeta_score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1261, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1544, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1365, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 216, in __call__
#     return self._score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1123, in f1_score
#     return fbeta_score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1261, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1544, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1365, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 216, in __call__
#     return self._score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1123, in f1_score
#     return fbeta_score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1261, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1544, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1365, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 216, in __call__
#     return self._score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1123, in f1_score
#     return fbeta_score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1261, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1544, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1365, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 216, in __call__
#     return self._score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1123, in f1_score
#     return fbeta_score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1261, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1544, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1365, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 216, in __call__
#     return self._score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1123, in f1_score
#     return fbeta_score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1261, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1544, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1365, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 216, in __call__
#     return self._score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1123, in f1_score
#     return fbeta_score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1261, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1544, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1365, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 216, in __call__
#     return self._score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1123, in f1_score
#     return fbeta_score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1261, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1544, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1365, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 216, in __call__
#     return self._score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1123, in f1_score
#     return fbeta_score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1261, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1544, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1365, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 216, in __call__
#     return self._score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1123, in f1_score
#     return fbeta_score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1261, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1544, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1365, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 216, in __call__
#     return self._score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1123, in f1_score
#     return fbeta_score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1261, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1544, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1365, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 216, in __call__
#     return self._score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1123, in f1_score
#     return fbeta_score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1261, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1544, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1365, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 216, in __call__
#     return self._score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1123, in f1_score
#     return fbeta_score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1261, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1544, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1365, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 216, in __call__
#     return self._score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1123, in f1_score
#     return fbeta_score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1261, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1544, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1365, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 216, in __call__
#     return self._score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1123, in f1_score
#     return fbeta_score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1261, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1544, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1365, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 216, in __call__
#     return self._score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1123, in f1_score
#     return fbeta_score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1261, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1544, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1365, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
# /Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 216, in __call__
#     return self._score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1123, in f1_score
#     return fbeta_score(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1261, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1544, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/Users/andishetavakkoli/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py", line 1365, in _check_set_wise_labels
#     raise ValueError(
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
#
#   warnings.warn(
